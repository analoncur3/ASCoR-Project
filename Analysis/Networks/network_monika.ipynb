# %% [markdown]
# # Create edgelist for network analysis of co-occuring words in newspaper titles

# %%
import numpy as np 
import re
import itertools
from itertools import combinations
import networkx as nx
import pandas as pd
#from scipy.spatial import distance
import matplotlib.pyplot as plt
#%matplotlib inline
from collections import defaultdict
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
#nltk.download('punkt')
#!pip install spacy
import spacy
#nlp = spacy.load('en_core_web_sm')
from spacy.language import Language
#save a sample of list
from random import sample
import operator
from itertools import count

# %%
data = pd.read_csv('preprocessed.csv', encoding='utf-8')
#data

# %%
#get a sample 
df2 = data.sample(500)

# %%
#download spacy en_core_web_sm if not downloaded alreadt
#!python -m spacy download en_core_web_sm
#load spacy model
nlp = spacy.load("en_core_web_sm") 


#add extra words you want to exclude
nlp.Defaults.stop_words.add('advertisement') 
nlp.Defaults.stop_words.add('s')
nlp.Defaults.stop_words.add('placeholder')
nlp.Defaults.stop_words.add('t')

print(nlp.Defaults.stop_words)
stopwords = nlp.Defaults.stop_words
# Out:
# {'’s', "'s", 'thereupon', 'at', 'itself', 'he', 'some', 'all', 'about', 'less', 'everyone', 'front', 'me', 'side', 'beyond', 'next', '’ll', 'only', 'again', 'around', 'indeed', 'when', 'afterwards', 'any', 'how', 'using', '’re', 'something', 'give', 'mostly', 't', 'either', 'him', 'twenty', 'often', "'m", 'whatever', 'nothing', "'re", 'throughout', 'never', 'be', 'has', 'herein', 'on', 'namely', 'hereupon', 'down', 'hence', 'everything', 'over', 'bottom', 'advertisement', 'who', 'per', 'i', 'others', 'towards', 'which', 'somehow', 'due', 'moreover', 'cannot', 'regarding', 'else', 'several', 'name', 'whither', 'off', 'under', 'among', 'will', 'beside', 'until', 'would', 'not', 'a', '‘s', 'therefore', 'become', 'nobody', 'you', 'go', 'amount', 'if', 'yours', 'just', 'someone', 'made', 'really', 'quite', 'hereafter', 'an', 'my', 'mine', 'for', 'already', 'wherein', 'did', 'the', 'serious', 'were', 'meanwhile', 'but', "'ve", 'thus', 'do', 'without', 'see', 'and', 's', 'against', 'can', 'before', 'move', '‘re', 'used', 'further', 'hereby', 'least', 'had', 'call', 'third', 'out', 'eleven', 'these', 'this', 'everywhere', 're', 'along', 'somewhere', 'am', 'n’t', 'most', 'same', 'her', 'does', 'three', 'since', 'every', 'anywhere', 'eight', '’m', 'as', 'twelve', 'full', 'well', 'onto', 'we', 'take', 'though', 'became', 'neither', 'what', 'seemed', 'placeholder', 'himself', 'more', 'together', 'unless', 'becoming', 'they', 'another', 'hers', 'many', 'perhaps', '‘d', 'by', 'ever', '’d', '‘m', 'across', 'so', 'nor', 'now', 'ca', 'yourselves', 'is', '’ve', 'none', 'except', 'why', 'two', 'please', 'few', 'below', 'there', 'its', 'whom', 'yet', 'noone', 'between', 'other', 'from', 'because', 'fifty', 'one', 'whereupon', 'beforehand', 'their', 'six', 'being', 'too', 'could', 'that', 'own', 'was', 'have', 'various', 'thence', 'upon', "n't", 'his', 'above', 'even', 'top', 'fifteen', 'than', 'through', 'formerly', 'yourself', 'still', 'thereby', 'or', 'anything', 'otherwise', '‘ll', '‘ve', 'them', 'empty', 'wherever', 'much', 'each', 'enough', 'may', 'latter', 'alone', 'put', 'to', 'n‘t', 'herself', 'elsewhere', 'becomes', 'nine', 'anyone', 'via', 'also', 'anyway', 'part', 'us', 'such', 'almost', 'behind', 'nowhere', 'toward', 'should', 'no', 'make', 'doing', 'amongst', 'she', 'first', 'myself', 'into', 'whereas', 'show', 'rather', 'always', 'within', 'latterly', 'however', 'therein', 'last', 'seeming', 'hundred', 'whence', 'ten', 'themselves', 'sometimes', 'whenever', 'very', 'whoever', "'ll", 'thru', 'done', 'after', 'say', 'while', 'whose', 'whereby', 'those', 'ours', 'keep', 'although', 'must', 'former', 'forty', 'both', 'anyhow', 'in', 'it', "'d", 'sixty', 'back', 'been', 'here', 'nevertheless', 'during', 'sometime', 'of', 'might', 'whereafter', 'thereafter', 'are', 'five', 'get', 'ourselves', 'where', 'up', 'with', 'four', 'whole', 'seems', 'seem', 'our', 'once', 'then', 'your', 'whether', 'besides'}

# %%
#con only do this once
#this makes sure that the tokenization considers entities

class EntityRetokenizeComponent:
    def __init__(self, nlp):
        pass

    def __call__(self, doc):
        with doc.retokenize() as retokenizer:
            for ent in doc.ents:
                retokenizer.merge(doc[ent.start:ent.end], attrs={"LEMMA": str(doc[ent.start:ent.end])})
        return doc

@Language.factory("entity_retokenizer_component")
def create_entity_retokenizer_component(nlp, name):
    return EntityRetokenizeComponent(nlp)

nlp = spacy.load("en_core_web_sm")  
nlp.add_pipe("entity_retokenizer_component", name='merge_phrases', last=True)


#rule to prevent spacy from splitting ID into I & D
nlp.tokenizer.rules = {key: value for key, value in nlp.tokenizer.rules.items() if key != "id"}

# %%
#test out the updated tokenizer
#doc = "German Chancellor Angela Merkel and US President Barack Obama (Donald Trump as id president-elect') converse in the Oval Office inside the White House in Washington, D.C."
#tokened_text = [token.text for token in nlp(doc)]
#tokened_text

# %%
#preprocess the text 
def preprocessing(corpus):
    '''this function preprocesses text. 
    It creates tokens, lowercases, 
    checks if str elements are actual words, 
    and then appends them to a list of clean '''
    clean_text = []

    for row in corpus:
        #tokens = [token.text for token in nlp(row)] spacy
        #word tokenize
        tokens = word_tokenize(row) #nltk
        #lowercase
        tokens = [token.lower() for token in tokens]
        # isword
        tokens = [token for token in tokens if token.isalpha()]
        #remove stopwords
        tokens = [word for word in tokens if not word in nlp.Defaults.stop_words]
        clean_sentence = ''
        clean_sentence = ' '.join(token for token in tokens)
        clean_text.append(clean_sentence)
       
    return clean_text

# %%
#take a sample to test out function
df2['clean_text'] = preprocessing(df2.astype(str)['maintext'])

# %%
#check if shiftwords in str
#read shifterator words
#we will make a co-occurance nwtwork of only texts that contain these classified words

shift_words = open('shiftwords_2.txt').read().splitlines()
df2['contains_shift'] = df2['clean_text'].str.contains('|'.join(shift_words)) #True or False based on condition
df2
# Out:
#             date                                           maintext  \
# 1234  2019/03/06  The Washington Post<U+0091>s fact checker gave...
# 549   2017/03/25  JEFFERSON CITY, Mo. (AP) - At the halfway poin...
# 3974  2018/09/12  This is part of a series on what is at stake i...
# 3756  2020/09/10  The president claims he is a champion of Black...
# 2935  2021/06/28  Three cheers for the Senate filibuster rule, w...
# ...          ...                                                ...
# 3517  2020/07/31  Barack Obama has spoken candidly about Preside...
# 427   2013/06/26  As weeks go for the Supreme Court, this one wa...
# 142   2013/08/26  Placeholder while article actions load\r\r\nWe...
# 1782  2020/09/18  Placeholder while article actions load\r\r\nSt...
# 3594  2019/05/07  Russian disinformation operations to exploit r...
#
#                                                   title  \
# 1234  WaPo Gives Clinton <U+0091>Four Pinocchios<U+0...
# 549   Missouri lawmakers return to pro-business agen...
# 3974                     Make Voting Easier in New York
# 3756  In Encounters With Black Leaders, Trump Has Ch...
# 2935  Failure of <U+0091>For the People Act<U+0092> ...
# ...                                                 ...
# 3517  Privately Slamming Trump, Obama Pulls In Over ...
# 427   Supreme Court Rulings on Marriage and Voting R...
# 142   Wonkbook: <U+0091>The biggest bubble of them a...
# 1782      What parents need to know about recent movies
# 3594  In 2016, Russians Worked To Discourage Black V...
#
#                                                  source          media_name  \
# 1234  https://freebeacon.com/politics/wapo-gives-cli...         Free Beacon
# 549   http://www.washingtontimes.com/news/2017/mar/2...    Washington Times
# 3974  C:/Users/analo/OneDrive - University of Glasgo...  The New York Times
# 3756  C:/Users/analo/OneDrive - University of Glasgo...  The New York Times
# 2935  https://nypost.com/2021/06/27/failure-of-for-t...             NY Post
# ...                                                 ...                 ...
# 3517  C:/Users/analo/OneDrive - University of Glasgo...  The New York Times
# 427   http://www.huffingtonpost.com/michael-sargeant...     Huffington Post
# 142   http://www.washingtonpost.com/blogs/ezra-klein...     Washington Post
# 1782  https://www.washingtonpost.com/goingoutguide/m...     Washington Post
# 3594  C:/Users/analo/OneDrive - University of Glasgo...  The New York Times
#
#      ideology Congress                                               text  \
# 1234    right    116th  washington post<u+0091>s fact checker gave two...
# 549     right    115th  jefferson city, mo. (ap) - halfway point 2017 ...
# 3974     left    115th  part series stake york<u+0092>s primary electi...
# 3756     left    116th  president claims champion black americans. wor...
# 2935    right    117th  cheers senate filibuster rule, requires 60 vot...
# ...       ...      ...                                                ...
# 3517     left    116th  barack obama spoken candidly president trump p...
# 427      left    113th  weeks supreme_court, historic. first, supreme_...
# 142      left    113th  placeholder article actions load wonkbook, ezr...
# 1782     left    116th  placeholder article actions load streaming wp ...
# 3594     left    116th  russian disinformation operations exploit raci...
#
#                                              clean_text  contains_shift
# 1234  washington post fact checker gave failed presi...            True
# 549   jefferson city mo ap halfway point session mis...            True
# 3974  series stake new york primary elections thursd...            True
# 3756  president claims champion black americans trie...            True
# 2935  cheers senate filibuster rule requires votes b...            True
# ...                                                 ...             ...
# 3517  barack obama spoken candidly president trump p...            True
# 427   weeks supreme court truly historic supreme cou...            True
# 142   article actions load welcome wonkbook ezra kle...            True
# 1782  article actions load streaming wp experience c...            True
# 3594  russian disinformation operations exploit raci...            True
#
# [500 rows x 10 columns]

# %%
#drop all rows that do not contain any of the shift words
df2 = df2.drop(df2[df2.contains_shift == False].index)

# %%
#clean title/text using the function on the whole dataset
#data['clean_title'] = preprocessing(data.astype(str)['title'])

# %% [markdown]
# ### Create edge list from text for igraph (this can take a long time ...)

# %%
texts = df2.clean_text.to_list()
for sentence in texts:
    tokenized = [token.text for token in nlp(sentence)]      
    edgelist = defaultdict(int)
    for node1, node2 in combinations(tokenized, 2):
        edgelist[(node1,node2)]+=1

#Save edgelist as .txt file
with open("edgelist1.txt", mode='w') as f:
    for k, v in edgelist.items():
        f.write(f"{k[0]},{k[1]},{v}\n")

# %%
#len(edgelist)

# %%
#we sort the edglist by value so that we can see what is the maximum which can inform us about where to make the cut
sorted_d = sorted(edgelist.items(), key=operator.itemgetter(1), reverse = True)
#print the list from top down to get an idea about how frequent are the occurances to be able to filter later on
sorted_d
# Out:
# [(('said', 'elections'), 112),
#  (('report', 'elections'), 96),
#  (('report', 'said'), 88),
#  (('said', 'voter'), 86),
#  (('voting', 'elections'), 81),
#  (('report', 'voter'), 79),
#  (('said', 'said'), 78),
#  (('report', 'voting'), 72),
#  (('said', 'voting'), 72),
#  (('voting', 'voter'), 67),
#  (('russian', 'elections'), 63),
#  (('interference', 'elections'), 61),
#  (('said', 'russian'), 60),
#  (('report', 'russian'), 58),
#  (('said', 'social'), 58),
#  (('voting', 'said'), 58),
#  (('russian', 'said'), 57),
#  (('voter', 'elections'), 57),
#  (('black', 'elections'), 55),
#  (('report', 'report'), 55),
#  (('said', 'report'), 55),
#  (('said', 'news'), 54),
#  (('black', 'said'), 53),
#  (('russian', 'voter'), 51),
#  (('report', 'social'), 49),
#  (('report', 'news'), 48),
#  (('interference', 'said'), 48),
#  (('said', 'internet'), 48),
#  (('voters', 'elections'), 48),
#  (('russian', 'voting'), 47),
#  (('interference', 'voter'), 47),
#  (('said', 'voters'), 47),
#  (('report', 'interference'), 45),
#  (('report', 'voters'), 45),
#  (('voting', 'voting'), 45),
#  (('elections', 'elections'), 45),
#  (('black', 'voter'), 44),
#  (('report', 'rights'), 43),
#  (('report', 'internet'), 43),
#  (('said', 'rights'), 43),
#  (('said', 'identification'), 43),
#  (('said', 'interference'), 43),
#  (('voting', 'russian'), 43),
#  (('voting', 'news'), 42),
#  (('voting', 'social'), 42),
#  (('russian', 'report'), 41),
#  (('black', 'voting'), 41),
#  (('states', 'elections'), 41),
#  (('efforts', 'elections'), 41),
#  (('interference', 'voting'), 39),
#  (('said', 'government'), 39),
#  (('said', 'negative'), 39),
#  (('identification', 'elections'), 39),
#  (('report', 'identification'), 38),
#  (('rights', 'elections'), 38),
#  (('voting', 'report'), 38),
#  (('elections', 'social'), 38),
#  (('elections', 'news'), 38),
#  (('black', 'report'), 37),
#  (('said', 'democratic'), 37),
#  (('russian', 'russian'), 36),
#  (('voter', 'voter'), 36),
#  (('rights', 'said'), 35),
#  (('voting', 'rights'), 35),
#  (('voting', 'internet'), 35),
#  (('states', 'voter'), 35),
#  (('voter', 'social'), 35),
#  (('morial', 'elections'), 35),
#  (('black', 'russian'), 34),
#  (('report', 'democratic'), 34),
#  (('said', 'states'), 34),
#  (('said', 'efforts'), 34),
#  (('voting', 'identification'), 34),
#  (('including', 'elections'), 34),
#  (('efforts', 'voter'), 34),
#  (('report', 'states'), 33),
#  (('report', 'efforts'), 33),
#  (('report', 'government'), 33),
#  (('report', 'negative'), 33),
#  (('rights', 'voter'), 33),
#  (('voting', 'voters'), 33),
#  (('voter', 'news'), 33),
#  (('elections', 'voter'), 33),
#  (('russian', 'interference'), 32),
#  (('russian', 'social'), 32),
#  (('interference', 'report'), 32),
#  (('said', 'media'), 32),
#  (('said', 'registration'), 32),
#  (('efforts', 'voting'), 32),
#  (('russian', 'news'), 31),
#  (('interference', 'russian'), 31),
#  (('interference', 'social'), 31),
#  (('said', 'north carolina'), 31),
#  (('said', 'bill'), 31),
#  (('voting', 'interference'), 31),
#  (('states', 'said'), 31),
#  (('voter', 'said'), 31),
#  (('voters', 'said'), 31),
#  (('voters', 'voter'), 31),
#  (('efforts', 'said'), 31),
#  (('russian', 'voters'), 30),
#  (('report', 'morial'), 30),
#  (('report', 'registration'), 30),
#  (('interference', 'news'), 30),
#  (('voting', 'government'), 30),
#  (('voting', 'negative'), 30),
#  (('voter', 'russian'), 30),
#  (('elections', 'internet'), 30),
#  (('democratic', 'elections'), 30),
#  (('russian', 'internet'), 29),
#  (('report', 'black'), 29),
#  (('said', 'process'), 29),
#  (('states', 'voting'), 29),
#  (('racial', 'elections'), 28),
#  (('black', 'voters'), 28),
#  (('black', 'social'), 28),
#  (('report', 'process'), 28),
#  (('report', 'north carolina'), 28),
#  (('said', 'federal'), 28),
#  (('said', 'investigations'), 28),
#  (('including', 'said'), 28),
#  (('voter', 'internet'), 28),
#  (('elections', 'negative'), 28),
#  (('russian', 'rights'), 27),
#  (('black', 'interference'), 27),
#  (('black', 'news'), 27),
#  (('report', 'media'), 27),
#  (('report', 'bill'), 27),
#  (('rights', 'russian'), 27),
#  (('interference', 'voters'), 27),
#  (('interference', 'internet'), 27),
#  (('said', 'morial'), 27),
#  (('voting', 'democratic'), 27),
#  (('voters', 'voting'), 27),
#  (('called', 'elections'), 27),
#  (('elections', 'russian'), 27),
#  (('russian', 'identification'), 26),
#  (('report', 'including'), 26),
#  (('report', 'federal'), 26),
#  (('report', 'investigations'), 26),
#  (('released', 'said'), 26),
#  (('said', 'networking'), 26),
#  (('said', 'organizations'), 26),
#  (('said', 'market'), 26),
#  (('said', 'demographics'), 26),
#  (('said', 'federation'), 26),
#  (('domestic', 'elections'), 26),
#  (('voters', 'social'), 26),
#  (('campaign', 'elections'), 26),
#  (('racial', 'said'), 25),
#  (('black', 'rights'), 25),
#  (('black', 'internet'), 25),
#  (('rights', 'voting'), 25),
#  (('said', 'black'), 25),
#  (('restrictions', 'elections'), 25),
#  (('voters', 'news'), 25),
#  (('going', 'elections'), 25),
#  (('morial', 'said'), 25),
#  (('morial', 'voter'), 25),
#  (('interference', 'identification'), 24),
#  (('said', 'including'), 24),
#  (('said', 'suppression'), 24),
#  (('said', 'political'), 24),
#  (('voting', 'north carolina'), 24),
#  (('voting', 'bill'), 24),
#  (('including', 'voter'), 24),
#  (('domestic', 'voter'), 24),
#  (('voter', 'negative'), 24),
#  (('laws', 'elections'), 24),
#  (('voters', 'russian'), 24),
#  (('called', 'said'), 24),
#  (('russian', 'efforts'), 23),
#  (('racial', 'voter'), 23),
#  (('sought', 'said'), 23),
#  (('black', 'identification'), 23),
#  (('rights', 'report'), 23),
#  (('interference', 'rights'), 23),
#  (('said', 'laws'), 23),
#  (('said', 'going'), 23),
#  (('said', 'legislative'), 23),
#  (('voting', 'registration'), 23),
#  (('domestic', 'said'), 23),
#  (('states', 'russian'), 23),
#  (('voter', 'identification'), 23),
#  (('voter', 'voters'), 23),
#  (('voter', 'voting'), 23),
#  (('voter', 'government'), 23),
#  (('campaign', 'voter'), 23),
#  (('elections', 'government'), 23),
#  (('process', 'elections'), 23),
#  (('russian', 'states'), 22),
#  (('russian', 'democratic'), 22),
#  (('report', 'going'), 22),
#  (('report', 'networking'), 22),
#  (('report', 'organizations'), 22),
#  (('report', 'market'), 22),
#  (('report', 'demographics'), 22),
#  (('report', 'federation'), 22),
#  (('national urban league', 'said'), 22),
#  (('rights', 'news'), 22),
#  (('rights', 'social'), 22),
#  (('said', 'election'), 22),
#  (('said', 'photo'), 22),
#  (('voting', 'federal'), 22),
#  (('voting', 'investigations'), 22),
#  (('voting', 'media'), 22),
#  (('states', 'report'), 22),
#  (('identification', 'said'), 22),
#  (('identification', 'voter'), 22),
#  (('research', 'said'), 22),
#  (('campaign', 'said'), 22),
#  (('twitter', 'said'), 22),
#  (('efforts', 'russian'), 22),
#  (('efforts', 'social'), 22),
#  (('efforts', 'report'), 22),
#  (('elections', 'rights'), 22),
#  (('north carolina', 'elections'), 22),
#  (('bill', 'elections'), 22),
#  (('russian', 'government'), 21),
#  (('russian', 'negative'), 21),
#  (('presidential', 'elections'), 21),
#  (('black', 'efforts'), 21),
#  (('interference', 'interference'), 21),
#  (('interference', 'democratic'), 21),
#  (('interference', 'government'), 21),
#  (('interference', 'negative'), 21),
#  (('said', 'foreign'), 21),
#  (('voting', 'including'), 21),
#  (('voting', 'states'), 21),
#  (('voting', 'morial'), 21),
#  (('voting', 'process'), 21),
#  (('states', 'news'), 21),
#  (('states', 'social'), 21),
#  (('voter', 'rights'), 21),
#  (('identification', 'news'), 21),
#  (('identification', 'social'), 21),
#  (('voters', 'report'), 21),
#  (('voters', 'internet'), 21),
#  (('account', 'said'), 21),
#  (('russian', 'black'), 20),
#  (('exploit', 'said'), 20),
#  (('racial', 'voting'), 20),
#  (('presidential', 'said'), 20),
#  (('election', 'elections'), 20),
#  (('sought', 'elections'), 20),
#  (('black', 'states'), 20),
#  (('report', 'restrictions'), 20),
#  (('report', 'laws'), 20),
#  (('report', 'election'), 20),
#  (('report', 'legislative'), 20),
#  (('report', 'foreign'), 20),
#  (('report', 'suppression'), 20),
#  (('report', 'political'), 20),
#  (('released', 'voting'), 20),
#  (('released', 'elections'), 20),
#  (('national urban league', 'elections'), 20),
#  (('rights', 'internet'), 20),
#  (('said', 'restrictions'), 20),
#  (('said', 'minority'), 20),
#  (('voting', 'networking'), 20),
#  (('voting', 'organizations'), 20),
#  (('voting', 'market'), 20),
#  (('voting', 'demographics'), 20),
#  (('voting', 'federation'), 20),
#  (('including', 'russian'), 20),
#  (('domestic', 'voting'), 20),
#  (('voter', 'report'), 20),
#  (('research', 'elections'), 20),
#  (('called', 'voter'), 20),
#  (('internet', 'elections'), 20),
#  (('twitter', 'elections'), 20),
#  (('account', 'elections'), 20),
#  (('efforts', 'news'), 20),
#  (('elections', 'media'), 20),
#  (('elections', 'organizations'), 20),
#  (('elections', 'market'), 20),
#  (('elections', 'demographics'), 20),
#  (('elections', 'federation'), 20),
#  (('racial', 'report'), 19),
#  (('presidential', 'voter'), 19),
#  (('black', 'democratic'), 19),
#  (('released', 'report'), 19),
#  (('rights', 'interference'), 19),
#  (('interference', 'efforts'), 19),
#  (('said', 'midterm'), 19),
#  (('said', 'presidential'), 19),
#  (('said', 'target'), 19),
#  (('said', 'passed'), 19),
#  (('said', 'ford'), 19),
#  (('voting', 'black'), 19),
#  (('including', 'voting'), 19),
#  (('restrictions', 'voter'), 19),
#  (('restrictions', 'said'), 19),
#  (('identification', 'russian'), 19),
#  (('morial', 'russian'), 19),
#  (('morial', 'voting'), 19),
#  (('elections', 'voting'), 19),
#  (('elections', 'federal'), 19),
#  (('democratic', 'voter'), 19),
#  (('russian', 'media'), 18),
#  (('russian', 'registration'), 18),
#  (('russian', 'north carolina'), 18),
#  (('russian', 'bill'), 18),
#  (('exploit', 'voting'), 18),
#  (('exploit', 'elections'), 18),
#  (('presidential', 'voting'), 18),
#  (('found', 'said'), 18),
#  (('found', 'elections'), 18),
#  (('sought', 'voting'), 18),
#  (('black', 'government'), 18),
#  (('black', 'negative'), 18),
#  (('report', 'campaign'), 18),
#  (('report', 'minority'), 18),
#  (('report', 'ford'), 18),
#  (('report', 'photo'), 18),
#  (('released', 'voter'), 18),
#  (('state', 'elections'), 18),
#  (('national urban league', 'voting'), 18),
#  (('rights', 'identification'), 18),
#  (('rights', 'voters'), 18),
#  (('interference', 'states'), 18),
#  (('said', 'intelligence'), 18),
#  (('said', 'russia'), 18),
#  (('said', 'people'), 18),
#  (('voting', 'laws'), 18),
#  (('voting', 'efforts'), 18),
#  (('voting', 'election'), 18),
#  (('voting', 'legislative'), 18),
#  (('voting', 'suppression'), 18),
#  (('voting', 'political'), 18),
#  (('including', 'report'), 18),
#  (('including', 'news'), 18),
#  (('including', 'social'), 18),
#  (('states', 'voters'), 18),
#  (('states', 'internet'), 18),
#  (('voter', 'federal'), 18),
#  (('voter', 'media'), 18),
#  (('voter', 'registration'), 18),
#  (('voter', 'organizations'), 18),
#  (('voter', 'market'), 18),
#  (('voter', 'demographics'), 18),
#  (('voter', 'federation'), 18),
#  (('voters', 'rights'), 18),
#  (('voters', 'government'), 18),
#  (('voters', 'negative'), 18),
#  (('campaign', 'voting'), 18),
#  (('called', 'voting'), 18),
#  (('accounts', 'said'), 18),
#  (('accounts', 'elections'), 18),
#  (('wokeluisa', 'said'), 18),
#  (('wokeluisa', 'elections'), 18),
#  (('discourage', 'elections'), 18),
#  (('going', 'voter'), 18),
#  (('efforts', 'internet'), 18),
#  (('efforts', 'voters'), 18),
#  (('efforts', 'rights'), 18),
#  (('morial', 'social'), 18),
#  (('elections', 'said'), 18),
#  (('elections', 'networking'), 18),
#  (('russian', 'federal'), 17),
#  (('russian', 'investigations'), 17),
#  (('russian', 'morial'), 17),
#  (('russian', 'process'), 17),
#  (('russian', 'federation'), 17),
#  (('exploit', 'voter'), 17),
#  (('racial', 'russian'), 17),
#  (('presidential', 'report'), 17),
#  (('election', 'said'), 17),
#  (('country', 'elections'), 17),
#  (('sought', 'report'), 17),
#  (('sought', 'voter'), 17),
#  (('black', 'morial'), 17),
#  (('report', 'domestic'), 17),
#  (('report', 'called'), 17),
#  (('report', 'people'), 17),
#  (('report', 'target'), 17),
#  (('report', 'passed'), 17),
#  (('monday', 'elections'), 17),
#  (('state', 'said'), 17),
#  (('national urban league', 'voter'), 17),
#  (('interference', 'media'), 17),
#  (('interference', 'registration'), 17),
#  (('interference', 'north carolina'), 17),
#  (('interference', 'bill'), 17),
#  (('said', 'campaign'), 17),
#  (('voting', 'restrictions'), 17),
#  (('voting', 'foreign'), 17),
#  (('politicians', 'elections'), 17),
#  (('states', 'identification'), 17),
#  (('states', 'interference'), 17),
#  (('states', 'rights'), 17),
#  (('gotten', 'elections'), 17),
#  (('worse', 'elections'), 17),
#  (('changes', 'elections'), 17),
#  (('voter', 'investigations'), 17),
#  (('voter', 'democratic'), 17),
#  (('voter', 'networking'), 17),
#  (('identification', 'voters'), 17),
#  (('identification', 'report'), 17),
#  (('identification', 'internet'), 17),
#  (('ballots', 'elections'), 17),
#  (('internet', 'said'), 17),
#  (('internet', 'social'), 17),
#  (('internet', 'voter'), 17),
#  (('discourage', 'said'), 17),
#  (('american', 'elections'), 17),
#  (('elections', 'investigations'), 17),
#  (('russian', 'including'), 16),
#  (('exploit', 'report'), 16),
#  (('election', 'voter'), 16),
#  (('found', 'voter'), 16),
#  (('black', 'including'), 16),
#  (('black', 'media'), 16),
#  (('report', 'american'), 16),
#  (('report', 'intelligence'), 16),
#  (('report', 'russia'), 16),
#  (('report', 'midterm'), 16),
#  (('report', 'presidential'), 16),
#  (('report', 'expanding'), 16),
#  (('released', 'russian'), 16),
#  (('interference', 'federal'), 16),
#  (('interference', 'investigations'), 16),
#  (('interference', 'process'), 16),
#  (('said', 'domestic'), 16),
#  (('said', 'american'), 16),
#  (('said', 'expanding'), 16),
#  (('voting', 'ford'), 16),
#  (('voting', 'photo'), 16),
#  (('including', 'voters'), 16),
#  (('including', 'internet'), 16),
#  (('domestic', 'report'), 16),
#  (('voter', 'interference'), 16),
#  (('voter', 'bill'), 16),
#  (('identification', 'voting'), 16),
#  (('laws', 'said'), 16),
#  (('research', 'voting'), 16),
#  (('research', 'voter'), 16),
#  (('called', 'report'), 16),
#  (('internet', 'russian'), 16),
#  (('accounts', 'voting'), 16),
#  (('accounts', 'voter'), 16),
#  (('twitter', 'voting'), 16),
#  (('twitter', 'voter'), 16),
#  (('account', 'voting'), 16),
#  (('account', 'voter'), 16),
#  (('wokeluisa', 'voting'), 16),
#  (('wokeluisa', 'voter'), 16),
#  (('discourage', 'voting'), 16),
#  (('discourage', 'voter'), 16),
#  (('going', 'said'), 16),
#  (('going', 'voting'), 16),
#  (('efforts', 'interference'), 16),
#  (('efforts', 'identification'), 16),
#  (('morial', 'news'), 16),
#  (('russia', 'elections'), 16),
#  (('schafer', 'voter'), 16),
#  (('schafer', 'elections'), 16),
#  (('democratic', 'social'), 16),
#  (('democratic', 'news'), 16),
#  (('want', 'voter'), 16),
#  (('want', 'elections'), 16),
#  (('expanding', 'elections'), 16),
#  (('russian', 'going'), 15),
#  (('presidential', 'russian'), 15),
#  (('black', 'black'), 15),
#  (('black', 'federal'), 15),
#  (('black', 'investigations'), 15),
#  (('black', 'registration'), 15),
#  (('black', 'north carolina'), 15),
#  (('black', 'bill'), 15),
#  (('report', 'petersburg'), 15),
#  (('report', 'company'), 15),
#  (('monday', 'said'), 15),
#  (('state', 'voter'), 15),
#  (('national urban league', 'report'), 15),
#  (('rights', 'rights'), 15),
#  (('rights', 'negative'), 15),
#  (('interference', 'black'), 15),
#  (('interference', 'morial'), 15),
#  (('said', 'petersburg'), 15),
#  (('said', 'company'), 15),
#  (('said', 'called'), 15),
#  (('domestic', 'russian'), 15),
#  (('states', 'government'), 15),
#  (('states', 'negative'), 15),
#  (('voter', 'north carolina'), 15),
#  (('identification', 'government'), 15),
#  (('identification', 'negative'), 15),
#  (('voters', 'interference'), 15),
#  (('voters', 'voters'), 15),
#  (('campaign', 'report'), 15),
#  (('called', 'russian'), 15),
#  (('internet', 'voting'), 15),
#  (('efforts', 'democratic'), 15),
#  (('efforts', 'states'), 15),
#  (('efforts', 'government'), 15),
#  (('efforts', 'negative'), 15),
#  (('elections', 'registration'), 15),
#  (('schafer', 'voting'), 15),
#  (('democratic', 'said'), 15),
#  (('people', 'elections'), 15),
#  (('target', 'elections'), 15),
#  (('passed', 'elections'), 15),
#  (('expanding', 'voter'), 15),
#  (('registration', 'elections'), 15),
#  (('ford', 'elections'), 15),
#  (('foreign', 'elections'), 15),
#  (('russian', 'election'), 14),
#  (('russian', 'laws'), 14),
#  (('russian', 'networking'), 14),
#  (('russian', 'organizations'), 14),
#  (('russian', 'market'), 14),
#  (('russian', 'demographics'), 14),
#  (('racial', 'interference'), 14),
#  (('racial', 'social'), 14),
#  (('presidential', 'social'), 14),
#  (('sought', 'russian'), 14),
#  (('black', 'going'), 14),
#  (('black', 'process'), 14),
#  (('report', 'racial'), 14),
#  (('released', 'interference'), 14),
#  (('national urban league', 'russian'), 14),
#  (('rights', 'democratic'), 14),
#  (('rights', 'government'), 14),
#  (('interference', 'including'), 14),
#  (('interference', 'networking'), 14),
#  (('interference', 'organizations'), 14),
#  (('interference', 'market'), 14),
#  (('interference', 'demographics'), 14),
#  (('interference', 'federation'), 14),
#  (('said', 'racial'), 14),
#  (('voting', 'going'), 14),
#  (('including', 'interference'), 14),
#  (('politicians', 'said'), 14),
#  (('states', 'democratic'), 14),
#  (('restrictions', 'russian'), 14),
#  (('gotten', 'said'), 14),
#  (('worse', 'said'), 14),
#  (('changes', 'said'), 14),
#  (('voter', 'political'), 14),
#  (('laws', 'voter'), 14),
#  (('voters', 'media'), 14),
#  (('ballots', 'said'), 14),
#  (('research', 'report'), 14),
#  (('campaign', 'russian'), 14),
#  (('campaign', 'social'), 14),
#  (('called', 'news'), 14),
#  (('called', 'social'), 14),
#  (('twitter', 'report'), 14),
#  (('news', 'russian'), 14),
#  (('morial', 'report'), 14),
#  (('morial', 'internet'), 14),
#  (('elections', 'report'), 14),
#  (('schafer', 'said'), 14),
#  (('democratic', 'russian'), 14),
#  (('want', 'voting'), 14),
#  (('process', 'voter'), 14),
#  (('photo', 'elections'), 14),
#  (('russian', 'restrictions'), 13),
#  (('russian', 'campaign'), 13),
#  (('russian', 'legislative'), 13),
#  (('russian', 'suppression'), 13),
#  (('russian', 'political'), 13),
#  (('disinformation', 'said'), 13),
#  (('operations', 'said'), 13),
#  (('racial', 'identification'), 13),
#  (('racial', 'voters'), 13),
#  (('racial', 'news'), 13),
#  (('tensions', 'said'), 13),
#  (('presidential', 'news'), 13),
#  (('election', 'report'), 13),
#  (('election', 'russian'), 13),
#  (('election', 'news'), 13),
#  (('united states', 'said'), 13),
#  (('found', 'report'), 13),
#  (('found', 'voting'), 13),
#  (('firm', 'said'), 13),
#  (('ground', 'said'), 13),
#  (('country', 'said'), 13),
#  (('legislators', 'said'), 13),
#  (('long', 'said'), 13),
#  (('suppress', 'said'), 13),
#  (('black', 'laws'), 13),
#  (('vote', 'said'), 13),
#  (('according', 'said'), 13),
#  (('report', 'civil'), 13),
#  (('report', 'politicians'), 13),
#  (('report', 'changes'), 13),
#  (('report', 'ballots'), 13),
#  (('america', 'said'), 13),
#  (('civil', 'said'), 13),
#  (('rights', 'states'), 13),
#  (('rights', 'federal'), 13),
#  (('organization', 'said'), 13),
#  (('based', 'said'), 13),
#  (('new york', 'said'), 13),
#  (('underlined', 'said'), 13),
#  (('interference', 'laws'), 13),
#  (('interference', 'going'), 13),
#  (('interference', 'suppression'), 13),
#  (('interference', 'political'), 13),
#  (('particular', 'said'), 13),
#  (('said', 'want'), 13),
#  (('said', 'country'), 13),
#  (('said', 'wants'), 13),
#  (('said', 'influence'), 13),
#  (('said', 'impact'), 13),
#  (('said', 'playing'), 13),
#  (('said', 'complete'), 13),
#  (('said', 'version'), 13),
#  (('said', 'story'), 13),
#  (('said', 'appeared'), 13),
#  (('said', 'print'), 13),
#  (('said', 'https'), 13),
#  (('said', 'classification'), 13),
#  (('said', 'language'), 13),
#  (('said', 'english'), 13),
#  (('said', 'newspaper'), 13),
#  (('said', 'subject'), 13),
#  (('said', 'campaigns'), 13),
#  (('said', 'heads'), 13),
#  (('said', 'bodies'), 13),
#  (('said', 'race'), 13),
#  (('said', 'ethnicity'), 13),
#  (('said', 'african americans'), 13),
#  (('said', 'right'), 13),
#  (('said', 'vote'), 13),
#  (('said', 'civil'), 13),
#  (('said', 'democracies'), 13),
#  (('said', 'law'), 13),
#  (('said', 'public'), 13),
#  (('said', 'administration'), 13),
#  (('said', 'services'), 13),
#  (('said', 'interviews'), 13),
#  (('said', 'groups'), 13),
#  (('said', 'politics'), 13),
#  (('said', 'types'), 13),
#  (('said',
#    'republican party crime law enforcement corrections negative personal'),
#   13),
#  (('said', 'misc'), 13),
#  (('said', 'special'), 13),
#  (('said', 'investigative'), 13),
#  (('said', 'forces'), 13),
#  (('said', 'human'), 13),
#  (('said', 'felonies'), 13),
#  (('said', 'associations'), 13),
#  (('said', 'facebook inc organization national urban league ticker'), 13),
#  (('said', 'fb'), 13),
#  (('said', 'nasdaq'), 13),
#  (('said', 'industry'), 13),
#  (('said', 'publishing'), 13),
#  (('said', 'broadcasting'), 13),
#  (('said', 'web'), 13),
#  (('said', 'search'), 13),
#  (('said', 'portals'), 13),
#  (('said', 'geographic'), 13),
#  (('said', 'saint'), 13),
#  (('said', 'new york usa'), 13),
#  (('said', 'united states'), 13),
#  (('voting', 'minority'), 13),
#  (('domestic', 'identification'), 13),
#  (('domestic', 'voters'), 13),
#  (('domestic', 'news'), 13),
#  (('domestic', 'social'), 13),
#  (('states', 'registration'), 13),
#  (('restrictions', 'report'), 13),
#  (('restrictions', 'news'), 13),
#  (('restrictions', 'social'), 13),
#  (('restrictions', 'voting'), 13),
#  (('voter', 'laws'), 13),
#  (('voter', 'process'), 13),
#  (('voter', 'suppression'), 13),
#  (('laws', 'report'), 13),
#  (('laws', 'russian'), 13),
#  (('laws', 'news'), 13),
#  (('laws', 'social'), 13),
#  (('voters', 'federal'), 13),
#  (('voters', 'investigations'), 13),
#  (('voters', 'democratic'), 13),
#  (('voters', 'registration'), 13),
#  (('voters', 'identification'), 13),
#  (('investigations', 'elections'), 13),
#  (('campaign', 'news'), 13),
#  (('called', 'voters'), 13),
#  (('internet', 'news'), 13),
#  (('account', 'report'), 13),
#  (('news', 'social'), 13),
#  (('going', 'social'), 13),
#  (('efforts', 'registration'), 13),
#  (('morial', 'interference'), 13),
#  (('morial', 'voters'), 13),
#  (('social', 'russian'), 13),
#  (('democratic', 'voting'), 13),
#  (('democratic', 'internet'), 13),
#  (('want', 'said'), 13),
#  (('expanding', 'voting'), 13),
#  (('russian', 'presidential'), 12),
#  (('russian', 'domestic'), 12),
#  (('russian', 'called'), 12),
#  (('russian', 'people'), 12),
#  (('russian', 'target'), 12),
#  (('russian', 'minority'), 12),
#  (('russian', 'ford'), 12),
#  (('russian', 'foreign'), 12),
#  (('russian', 'photo'), 12),
#  (('exploit', 'russian'), 12),
#  (('racial', 'rights'), 12),
#  (('racial', 'internet'), 12),
#  (('presidential', 'rights'), 12),
#  (('presidential', 'internet'), 12),
#  (('election', 'voting'), 12),
#  (('found', 'russian'), 12),
#  (('sought', 'interference'), 12),
#  (('black', 'restrictions'), 12),
#  (('black', 'networking'), 12),
#  (('black', 'organizations'), 12),
#  (('black', 'market'), 12),
#  (('black', 'demographics'), 12),
#  (('black', 'federation'), 12),
#  (('vote', 'elections'), 12),
#  (('report', 'gotten'), 12),
#  (('report', 'worse'), 12),
#  (('report', 'want'), 12),
#  (('released', 'rights'), 12),
#  (('released', 'voters'), 12),
#  (('monday', 'report'), 12),
#  (('monday', 'voting'), 12),
#  (('monday', 'voter'), 12),
#  (('state', 'voting'), 12),
#  (('national urban league', 'interference'), 12),
#  (('civil', 'elections'), 12),
#  (('rights', 'including'), 12),
#  (('rights', 'investigations'), 12),
#  (('rights', 'efforts'), 12),
#  (('rights', 'morial'), 12),
#  (('rights', 'media'), 12),
#  (('rights', 'north carolina'), 12),
#  (('rights', 'bill'), 12),
#  (('rights', 'organizations'), 12),
#  (('rights', 'market'), 12),
#  (('rights', 'demographics'), 12),
#  (('rights', 'federation'), 12),
#  (('interference', 'election'), 12),
#  (('interference', 'legislative'), 12),
#  (('interference', 'photo'), 12),
#  (('said', 'politicians'), 12),
#  (('said', 'gotten'), 12),
#  (('said', 'worse'), 12),
#  (('said', 'changes'), 12),
#  (('said', 'ballots'), 12),
#  (('said', 'schafer'), 12),
#  (('said', 'hoped'), 12),
#  (('said', 'congress'), 12),
#  (('said', 'hold'), 12),
#  (('said', 'hearings'), 12),
#  (('said', 'tell'), 12),
#  (('said', 'today'), 12),
#  (('said', 'china'), 12),
#  (('said', 'tomorrow saudi arabia week'), 12),
#  (('voting', 'campaign'), 12),
#  (('voting', 'petersburg'), 12),
#  (('voting', 'company'), 12),
#  (('voting', 'called'), 12),
#  (('voting', 'intelligence'), 12),
#  (('voting', 'midterm'), 12),
#  (('voting', 'presidential'), 12),
#  (('voting', 'target'), 12),
#  (('attack', 'said'), 12),
#  (('wide', 'said'), 12),
#  (('range', 'said'), 12),
#  (('actors', 'said'), 12),
#  (('including', 'efforts'), 12),
#  (('including', 'rights'), 12),
#  (('including', 'government'), 12),
#  (('including', 'negative'), 12),
#  (('domestic', 'interference'), 12),
#  (('politicians', 'voter'), 12),
#  (('dozen', 'said'), 12),
#  (('states', 'process'), 12),
#  (('states', 'north carolina'), 12),
#  (('states', 'bill'), 12),
#  (('gotten', 'voter'), 12),
#  (('worse', 'voter'), 12),
#  (('changes', 'voter'), 12),
#  (('new', 'said'), 12),
#  (('voter', 'photo'), 12),
#  (('voter', 'including'), 12),
#  (('identification', 'democratic'), 12),
#  (('identification', 'rights'), 12),
#  (('laws', 'voters'), 12),
#  (('laws', 'voting'), 12),
#  (('decisions', 'said'), 12),
#  (('limit', 'said'), 12),
#  (('locations', 'said'), 12),
#  (('voters', 'efforts'), 12),
#  (('voters', 'states'), 12),
#  (('voters', 'networking'), 12),
#  (('voters', 'organizations'), 12),
#  (('voters', 'market'), 12),
#  (('voters', 'demographics'), 12),
#  (('voters', 'federation'), 12),
#  (('cast', 'said'), 12),
#  (('research', 'russian'), 12),
#  (('campaign', 'internet'), 12),
#  (('campaign', 'voters'), 12),
#  (('campaign', 'identification'), 12),
#  (('called', 'internet'), 12),
#  (('internet', 'report'), 12),
#  (('accounts', 'report'), 12),
#  (('twitter', 'russian'), 12),
#  (('account', 'russian'), 12),
#  (('wokeluisa', 'report'), 12),
#  (('news', 'elections'), 12),
#  (('news', 'internet'), 12),
#  (('news', 'voter'), 12),
#  (('going', 'russian'), 12),
#  (('going', 'news'), 12),
#  (('efforts', 'media'), 12),
#  (('efforts', 'process'), 12),
#  (('efforts', 'north carolina'), 12),
#  (('efforts', 'bill'), 12),
#  (('morial', 'rights'), 12),
#  (('morial', 'identification'), 12),
#  (('morial', 'government'), 12),
#  (('morial', 'negative'), 12),
#  (('elections', 'voters'), 12),
#  (('elections', 'political'), 12),
#  (('social', 'elections'), 12),
#  (('social', 'news'), 12),
#  (('democratic', 'government'), 12),
#  (('democratic', 'negative'), 12),
#  (('process', 'social'), 12),
#  (('process', 'news'), 12),
#  (('north carolina', 'voter'), 12),
#  (('north carolina', 'social'), 12),
#  (('north carolina', 'news'), 12),
#  (('bill', 'social'), 12),
#  (('bill', 'news'), 12),
#  (('russian', 'intelligence'), 11),
#  (('russian', 'russia'), 11),
#  (('russian', 'midterm'), 11),
#  (('russian', 'passed'), 11),
#  (('disinformation', 'report'), 11),
#  (('operations', 'report'), 11),
#  (('racial', 'democratic'), 11),
#  (('tensions', 'report'), 11),
#  (('presidential', 'interference'), 11),
#  (('election', 'social'), 11),
#  (('united states', 'report'), 11),
#  (('firm', 'report'), 11),
#  (('ground', 'report'), 11),
#  (('country', 'report'), 11),
#  (('country', 'voting'), 11),
#  (('country', 'voter'), 11),
#  (('legislators', 'report'), 11),
#  (('long', 'report'), 11),
#  (('sought', 'voters'), 11),
#  (('suppress', 'report'), 11),
#  (('black', 'domestic'), 11),
#  (('black', 'campaign'), 11),
#  (('black', 'called'), 11),
#  (('black', 'election'), 11),
#  (('black', 'legislative'), 11),
#  (('black', 'suppression'), 11),
#  (('black', 'political'), 11),
#  (('vote', 'report'), 11),
#  (('vote', 'voter'), 11),
#  (('according', 'report'), 11),
#  (('report', 'state'), 11),
#  (('report', 'discourage'), 11),
#  (('report', 'schafer'), 11),
#  (('report', 'annual'), 11),
#  (('report', 'edition'), 11),
#  (('report', 'featured'), 11),
#  (('report', 'essays'), 11),
#  (('report', 'written'), 11),
#  (('report', 'authors'), 11),
#  (('report', 'scholars'), 11),
#  (('report', 'corporate'), 11),
#  (('report', 'executives'), 11),
#  (('report', 'recommended'), 11),
#  (('report', 'number'), 11),
#  (('report', 'policy'), 11),
#  (('report', 'automatic'), 11),
#  (('report', 'creation'), 11),
#  (('report', 'national'), 11),
#  (('report', 'commission'), 11),
#  (('report', 'identify'), 11),
#  (('report', 'eliminate'), 11),
#  (('report', 'postelection'), 11),
#  (('report', 'auditing'), 11),
#  (('report', 'compare'), 11),
#  (('report', 'paper'), 11),
#  (('report', 'computerized'), 11),
#  (('report', 'tabulations'), 11),
#  (('report', 'hoped'), 11),
#  (('report', 'congress'), 11),
#  (('report', 'hold'), 11),
#  (('report', 'hearings'), 11),
#  (('report', 'tell'), 11),
#  (('report', 'today'), 11),
#  (('report', 'china'), 11),
#  (('report', 'tomorrow saudi arabia week'), 11),
#  (('report', 'country'), 11),
#  (('report', 'wants'), 11),
#  (('report', 'influence'), 11),
#  (('report', 'impact'), 11),
#  (('report', 'playing'), 11),
#  (('report', 'complete'), 11),
#  (('report', 'version'), 11),
#  (('report', 'story'), 11),
#  (('report', 'appeared'), 11),
#  (('report', 'print'), 11),
#  (('report', 'https'), 11),
#  (('report', 'classification'), 11),
#  (('report', 'language'), 11),
#  (('report', 'english'), 11),
#  (('report', 'newspaper'), 11),
#  (('report', 'subject'), 11),
#  (('report', 'campaigns'), 11),
#  (('report', 'heads'), 11),
#  (('report', 'bodies'), 11),
#  (('report', 'race'), 11),
#  (('report', 'ethnicity'), 11),
#  (('report', 'african americans'), 11),
#  (('report', 'right'), 11),
#  (('report', 'vote'), 11),
#  (('report', 'democracies'), 11),
#  (('report', 'law'), 11),
#  (('report', 'public'), 11),
#  (('report', 'administration'), 11),
#  (('report', 'services'), 11),
#  (('report', 'interviews'), 11),
#  (('report', 'groups'), 11),
#  (('report', 'politics'), 11),
#  (('report', 'types'), 11),
#  (('report',
#    'republican party crime law enforcement corrections negative personal'),
#   11),
#  (('report', 'misc'), 11),
#  (('report', 'special'), 11),
#  (('report', 'investigative'), 11),
#  (('report', 'forces'), 11),
#  (('report', 'human'), 11),
#  (('report', 'felonies'), 11),
#  (('report', 'associations'), 11),
#  (('report', 'facebook inc organization national urban league ticker'), 11),
#  (('report', 'fb'), 11),
#  (('report', 'nasdaq'), 11),
#  (('report', 'industry'), 11),
#  (('report', 'publishing'), 11),
#  (('report', 'broadcasting'), 11),
#  (('report', 'web'), 11),
#  (('report', 'search'), 11),
#  (('report', 'portals'), 11),
#  (('report', 'geographic'), 11),
#  (('report', 'saint'), 11),
#  (('report', 'new york usa'), 11),
#  (('report', 'united states'), 11),
#  (('monday', 'russian'), 11),
#  (('state', 'russian'), 11),
#  (('state', 'report'), 11),
#  (('rights', 'black'), 11),
#  (('rights', 'registration'), 11),
#  (('interference', 'restrictions'), 11),
#  (('interference', 'people'), 11),
#  (('interference', 'target'), 11),
#  (('interference', 'minority'), 11),
#  (('interference', 'ford'), 11),
#  (('interference', 'foreign'), 11),
#  (('said', 'man'), 11),
#  (('said', 'sensitive'), 11),
#  (('said', 'discriminatory'), 11),
#  (('said', 'tactics'), 11),
#  (('said', 'blanket'), 11),
#  (('said', 'opposition'), 11),
#  (('said', 'unnecessary'), 11),
#  (('said', 'wedge'), 11),
#  (('said', 'issue'), 11),
#  (('said', 'crafted'), 11),
#  (('said', 'minimize'), 11),
#  (('said', 'discrimination'), 11),
#  (('said', 'added'), 11),
#  (('said', 'necessary'), 11),
#  (('said', 'activities'), 11),
#  (('said', 'like'), 11),
#  (('said', 'banking'), 11),
#  (('said', 'flying'), 11),
#  (('said', 'supported'), 11),
#  (('said', 'allowed'), 11),
#  (('said', 'obtain'), 11),
#  (('said', 'cards'), 11),
#  (('said', 'cost'), 11),
#  (('said', 'december'), 11),
#  (('said', 'legislature'), 11),
#  (('said', 'overrode'), 11),
#  (('said', 'governor'), 11),
#  (('said', 'veto'), 11),
#  (('said', 'monday'), 11),
#  (('said', 'named'), 11),
#  (('said', 'annual'), 11),
#  (('said', 'edition'), 11),
#  (('said', 'featured'), 11),
#  ...]

# %%
#filter edges based on weight (aka the frequency of co-occurance) 
filtered = {k: v for k, v in edgelist.items() if v > 10}
#len(filtered)

# %%
#save filtered edgelist for network analysis
with open("filtered_3.txt", mode='w') as f:
    for k, v in filtered.items():
        f.write(f"{k[0]},{k[1]},{v}\n")

# %% [markdown]
# # Network analysis

# %%
#create graph object
G = nx.read_weighted_edgelist('filtered_3.txt', delimiter=',')
#get edge list data
#G.edges.data()
#G.remove_nodes_from(list(nx.isolates(G)))

# %% [markdown]
# #### Add node attributes from shifterator scores (see other notebook)

# %%
node_attr = pd.read_csv('shifterator_2.csv' )

# %%
#make all numbers absolute so that they can be used for node sizes
node_attr['score'] = node_attr['score'].abs()

# %%
#node_attr
#create dict that contains node attributes to be merged with the network graph (G) later on 
node_attributes = node_attr.to_dict('records')

# %%
#create node2attributemap to be merged with nodes 
node2attributemap = {n['word']: {'leaning': n['left_right'], 'score':n['score']} for n in node_attributes}
# print(node2attributemap)
#set node attributes to the Graph
nx.set_node_attributes(G, node2attributemap)

# %%
#we see that we managed to add node attributes to the graph object
G.nodes.data()
# Out:
# NodeDataView({'russian': {'leaning': 'right', 'score': 0.000313441403407}, 'presidential': {'leaning': 'left', 'score': 0.0014708957334581}, 'election': {'leaning': 'right', 'score': 0.0008919630952771}, 'black': {'leaning': 'left', 'score': 0.0015513826526627}, 'report': {'leaning': 'right', 'score': 0.0003519277239608}, 'rights': {'leaning': 'left', 'score': 0.0032534640193015}, 'interference': {'leaning': 'left', 'score': 8.112514751762269e-05}, 'said': {'leaning': 'left', 'score': 0.0013085439841424}, 'voting': {'leaning': 'left', 'score': 0.0029488588560597}, 'including': {'leaning': 'right', 'score': 2.96915093910357e-06}, 'domestic': {'leaning': 'right', 'score': 0.0001317606319067}, 'states': {'leaning': 'left', 'score': 0.0006790802855195}, 'restrictions': {'leaning': 'left', 'score': 0.0009194387245269}, 'voter': {'leaning': 'right', 'score': 0.0007522584606695}, 'identification': {'leaning': 'right', 'score': 0.0002017789210582}, 'laws': {'leaning': 'right', 'score': 0.0006166906710735}, 'voters': {'leaning': 'left', 'score': 0.0020187783418131}, 'federal': {'leaning': 'left', 'score': 0.0005076529645836}, 'investigations': {'leaning': 'left', 'score': 0.0003051169445911}, 'campaign': {'leaning': 'left', 'score': 0.0007092955920094}, 'called': {'leaning': 'right', 'score': 0.000246140931932}, 'internet': {'leaning': 'left', 'score': 3.64873858860538e-05}, 'news': {'leaning': 'right', 'score': 0.0007345517509698}, 'going': {'leaning': 'right', 'score': 0.0027270073457461}, 'efforts': {'leaning': 'left', 'score': 0.0003690690631276}, 'morial': {'leaning': 'left', 'score': 2.019878958566542e-06}, 'elections': {'leaning': 'left', 'score': 0.0004488519956822}, 'intelligence': {'leaning': 'right', 'score': 1.1149671289960842e-05}, 'russia': {'leaning': 'right', 'score': 0.0005853787399074}, 'midterm': {'leaning': 'left', 'score': 0.0005131767317058}, 'social': {'leaning': 'left', 'score': 2.602507266248333e-06}, 'media': {'leaning': 'right', 'score': 0.0014120693801686}, 'democratic': {'leaning': 'left', 'score': 0.001266417456808}, 'people': {'leaning': 'right', 'score': 0.0016278485410342}, 'target': {'leaning': 'left', 'score': 0.0001234791955516}, 'minority': {'leaning': 'left', 'score': 0.0005917676144242}, 'passed': {'leaning': 'left', 'score': 0.0001135842724211}, 'registration': {'leaning': 'left', 'score': 0.0011244772509792}, 'process': {'leaning': 'left', 'score': 6.685571314530701e-06}, 'ford': {'leaning': 'right', 'score': 8.549088704768465e-05}, 'north carolina': {}, 'bill': {'leaning': 'right', 'score': 0.0024170305378592}, 'legislative': {'leaning': 'left', 'score': 0.0003463552267697}, 'foreign': {'leaning': 'right', 'score': 0.0001819178146309}, 'suppression': {'leaning': 'left', 'score': 0.0003057454957526}, 'political': {'leaning': 'left', 'score': 0.0022680156386792}, 'photo': {'leaning': 'right', 'score': 0.0002491384159259}, 'government': {'leaning': 'left', 'score': 0.0004497938894833}, 'networking': {'leaning': 'left', 'score': 0.0001084797402831}, 'negative': {'leaning': 'left', 'score': 6.906044012083964e-05}, 'organizations': {'leaning': 'left', 'score': 0.000241057659387}, 'market': {'leaning': 'left', 'score': 7.5392938279635e-05}, 'demographics': {'leaning': 'left', 'score': 9.8847490705225e-05}, 'federation': {'leaning': 'left', 'score': 1.33976701433732e-05}, 'disinformation': {'leaning': 'right', 'score': 4.911542394037362e-05}, 'operations': {'leaning': 'right', 'score': 1.0258068815325602e-05}, 'exploit': {'leaning': 'left', 'score': 1.0948937957012572e-06}, 'racial': {'leaning': 'left', 'score': 0.0008180051938291}, 'tensions': {'leaning': 'left', 'score': 7.098746675045552e-05}, 'united states': {}, 'found': {'leaning': 'left', 'score': 0.0002334021153742}, 'firm': {'leaning': 'right', 'score': 9.148520385598476e-05}, 'ground': {'leaning': 'left', 'score': 0.0001020427511763}, 'country': {'leaning': 'right', 'score': 0.0007192645368521}, 'legislators': {'leaning': 'left', 'score': 0.0 ...

# %%
size_map = nx.get_node_attributes(G, "score")
size = list(size_map.values())

# %%
#size_map
# Out:
# {'russian': 0.000313441403407,
#  'exploit': 1.0948937957012572e-06,
#  'racial': 0.0008180051938291,
#  'presidential': 0.0014708957334581,
#  'election': 0.0008919630952771,
#  'found': 0.0002334021153742,
#  'country': 0.0007192645368521,
#  'black': 0.0015513826526627,
#  'vote': 0.0007408734515431,
#  'report': 0.0003519277239608,
#  'monday': 0.0001444415330561,
#  'state': 0.0017716618347265,
#  'civil': 0.0017351126961619,
#  'rights': 0.0032534640193015,
#  'interference': 8.112514751762269e-05,
#  'said': 0.0013085439841424,
#  'voting': 0.0029488588560597,
#  'including': 2.96915093910357e-06,
#  'domestic': 0.0001317606319067,
#  'politicians': 0.0001854537768046,
#  'states': 0.0006790802855195,
#  'restrictions': 0.0009194387245269,
#  'gotten': 9.241460011805429e-06,
#  'worse': 0.0003766548629205,
#  'changes': 0.0002636135360873,
#  'voter': 0.0007522584606695,
#  'identification': 0.0002017789210582,
#  'laws': 0.0006166906710735,
#  'voters': 0.0020187783418131,
#  'ballots': 0.0010353451162506,
#  'research': 8.680885418141284e-05,
#  'federal': 0.0005076529645836,
#  'investigations': 0.0003051169445911,
#  'campaign': 0.0007092955920094,
#  'company': 9.857900941977288e-05,
#  'called': 0.000246140931932,
#  'internet': 3.64873858860538e-05,
#  'accounts': 8.920369194434406e-05,
#  'twitter': 0.0002653006546287,
#  'account': 1.3513668704053875e-05,
#  'news': 0.0007345517509698,
#  'discourage': 5.846734970799258e-05,
#  'going': 0.0027270073457461,
#  'efforts': 0.0003690690631276,
#  'morial': 2.019878958566542e-06,
#  'american': 0.0006465666807776,
#  'elections': 0.0004488519956822,
#  'intelligence': 1.1149671289960842e-05,
#  'russia': 0.0005853787399074,
#  'midterm': 0.0005131767317058,
#  'schafer': 2.3192563015357416e-05,
#  'social': 2.602507266248333e-06,
#  'media': 0.0014120693801686,
#  'democratic': 0.001266417456808,
#  'people': 0.0016278485410342,
#  'want': 0.0022106267722345,
#  'target': 0.0001234791955516,
#  'minority': 0.0005917676144242,
#  'passed': 0.0001135842724211,
#  'expanding': 4.3441922260632765e-05,
#  'registration': 0.0011244772509792,
#  'process': 6.685571314530701e-06,
#  'factors': 0.0001040264199482,
#  'determined': 6.093919347982819e-05,
#  'turnout': 0.0014510894619321,
#  'involved': 2.148654473090485e-05,
#  'targeting': 2.339865182637569e-05,
#  'joel': 5.928465791982055e-05,
#  'ford': 8.549088704768465e-05,
#  'senator': 0.0004176229581229,
#  'sponsor': 2.2762821465957696e-05,
#  'bill': 0.0024170305378592,
#  'disagreed': 1.778830409071246e-05,
#  'think': 0.002236978391755,
#  'separate': 9.45979393537927e-05,
#  'issues': 0.0003021136086313,
#  'americans': 0.0007707750671949,
#  'control': 0.0001149028984004,
#  'legislative': 0.0003463552267697,
#  'foreign': 0.0001819178146309,
#  'man': 0.0001063775109168,
#  'sensitive': 3.852864093103105e-05,
#  'discriminatory': 0.0003054495849222,
#  'suppression': 0.0003057454957526,
#  'tactics': 0.0002380063646864,
#  'blanket': 3.59674688140836e-05,
#  'opposition': 0.0001195929651022,
#  'unnecessary': 4.457835256985198e-05,
#  'political': 0.0022680156386792,
#  'wedge': 5.537029806304433e-06,
#  'issue': 3.332400684611193e-05,
#  'crafted': 3.2071028877036814e-05,
#  'minimize': 4.207233184631937e-05,
#  'discrimination': 0.0011742900161049,
#  'added': 0.0003974366343957,
#  'photo': 0.0002491384159259,
#  'necessary': 3.693767470527965e-05,
#  'activities': 4.195107002061937e-05,
#  'like': 0.0010618275731619,
#  'banking': 4.0995986900881685e-05,
#  'flying': 7.058500161035875e-05,
#  'supported': 0.0001872944684952,
#  'allowed': 3.098942958760462e-05,
#  'obtain': 1.2448366719374795e-05,
#  'cards': 2.774994453770881e-05,
#  'cost': 1.6108129852459533e-05,
#  'december': 5.1205874292335166e-05,
#  'legislature': 0.0004506792261802,
#  'overrode': 3.1976592150543965e-05,
#  'governor': 0.0003094240077384,
#  'veto': 4.664225769093498e-05,
#  'named': 6.303046262027348e-05,
#  'annual': 4.058652957808886e-06,
#  'edition': 7.847573756350315e-05,
#  'featured': 1.848591787010291e-07,
#  'essays': 7.396632803373414e-06,
#  'written': 6.917800053517719e-05,
#  'authors': 0.0001076634771295,
#  'scholars': 9.488062763722266e-05,
#  'corporate': 0.0003429198538019,
#  'executives': 6.232882816618479e-05,
#  'recommended': 5.978391658580404e-05,
#  'number': 1.5185722030908755e-05,
#  'policy': 0.0001869406598942,
#  'automatic': 8.037913121070935e-05,
#  'creation': 7.353811038666133e-05,
#  'national': 0.0002834707883425,
#  'commission': 0.0001497189144862,
#  'identify': 4.029471124420584e-05,
#  'eliminate': 7.908463867712741e-05,
#  'postelection': 2.3808635888539256e-05,
#  'auditing': 1.583951776644346e-05,
#  'compare': 0.000139225931761,
#  'paper': 1.0179646517773054e-05,
#  'computerized': 1.9617061657678954e-05,
#  'tabulations': 2.109227155221983e-06,
#  'hoped': 8.426932925702785e-05,
#  'congress': 0.0004532060215949,
#  'hold': 3.1871246117649624e-05,
#  'hearings': 0.0001235121706306,
#  'tell': 0.0006162928339076,
#  'today': 0.000132592716402,
#  'china': 0.0008110426780081,
#  'wants': 0.0005960659096807,
#  'influence': 0.000152664872209,
#  'impact': 0.0003215967165271,
#  'playing': 8.630978974918848e-05,
#  'complete': 7.269461245576994e-07,
#  'version': 5.454866674636448e-05,
#  'story': 5.979599602888282e-05,
#  'appeared': 0.0002371682969589,
#  'print': 6.468424285993028e-05,
#  'classification': 0.0003471359285882,
#  'language': 0.0003392191835845,
#  'english': 0.0005284744837614,
#  'newspaper': 0.0002241824381481,
#  'subject': 0.0005389224935241,
#  'campaigns': 0.0001602704281747,
#  'heads': 3.1725175069571536e-05,
#  'government': 0.0004497938894833,
#  'bodies': 4.769995103989205e-05,
#  'race': 0.000582277801093,
#  'ethnicity': 0.0001040641185349,
#  'right': 0.0009468763562194,
#  'networking': 0.0001084797402831,
#  'democracies': 0.0004277866811777,
#  'law': 0.0001538366365584,
#  'public': 0.0003522273477222,
#  'administration': 0.0002274023159694,
#  'services': 9.499219250933332e-05,
#  'interviews': 0.0002664450187461,
#  'groups': 0.0009281441426672,
#  'negative': 6.906044012083964e-05,
#  'politics': 0.0014139246300744,
#  'types': 1.5903396628571844e-05,
#  'misc': 9.150224839312704e-06,
#  'special': 0.0001086576867021,
#  'investigative': 5.246379933633091e-05,
#  'forces': 3.083205815715203e-05,
#  'human': 1.703043672453691e-05,
#  'organizations': 0.000241057659387,
#  'market': 7.5392938279635e-05,
#  'demographics': 9.8847490705225e-05,
#  'felonies': 0.0002098470327992,
#  'associations': 1.0170696675120372e-05,
#  'fb': 5.0232756908649855e-05,
#  'nasdaq': 7.519193115373298e-05,
#  'industry': 0.0008789775423647,
#  'publishing': 0.0002312632923013,
#  'broadcasting': 9.652733524077924e-06,
#  'web': 0.0006774110610011,
#  'search': 4.824414488183487e-05,
#  'portals': 6.929404234287971e-05,
#  'geographic': 0.0011179982744938,
#  'saint': 3.364837864632441e-06,
#  'federation': 1.33976701433732e-05,
#  'disinformation': 4.911542394037362e-05,
#  'operations': 1.0258068815325602e-05,
#  'tensions': 7.098746675045552e-05,
#  'firm': 9.148520385598476e-05,
#  'ground': 0.0001020427511763,
#  'legislators': 0.0003595865908138,
#  'long': 0.000502115857146,
#  'sought': 0.0003093773554151,
#  'suppress': 1.1273301531089275e-05,
#  'according': 0.0001353807758667,
#  'described': 7.860649963632088e-05,
#  'fake': 0.0001270475659692,
#  'impersonated': 4.3684683930395706e-05,
#  'animosity': 1.9617061657678954e-05,
#  'moving': 0.000170889165148,
#  'dial': 5.830433966988925e-06,
#  'couple': 1.5546834854433736e-05,
#  'degrees': 7.926625433830666e-05,
#  'direction': 4.382261519437845e-06,
#  'interview': 0.000102932362099,
#  'anonymity': 2.3971762290927715e-05,
#  'allows': 0.0002060392493552,
#  'course': 0.00053551458899,
#  'far': 0.0001497198612976,
#  'persuasive': 3.068672192912459e-05,
#  'audience': 0.0002219437092707,
#  'thinks': 5.283621282010592e-05,
#  'outlined': 5.736688162517178e-05,
#  'empower': 2.8925810001549238e-06,
#  'disenfranchise': 0.0001135947315873,
#  'citing': 9.023890415004708e-05,
#  'data': 0.0004621638401362,
#  'compiled': 4.106285548058089e-05,
#  'brennan': 2.374979726707116e-05,
#  'center': 0.0003213060310055,
#  'justice': 0.0013625754174616,
#  'march': 0.0001764830314423,
#  'considering': 4.854610942279765e-05,
#  'bills': 0.0005792264032263,
#  'access': 0.0004145806396322,
#  'instance': 0.0001718757763297,
#  'easing': 1.242004720979758e-05,
#  'early': 0.0004099209675643,
#  'giving': 0.0001418025700153,
#  'convicted': 6.339980569758656e-05,
#  'felons': 0.0001151428492383,
#  'vast': 5.364965571949852e-05,
#  'majority': 0.0002213829506828,
#  'imposed': 0.0001427752113004,
#  'republicans': 0.001347710155753,
#  'proliferated': 1.1420581922201551e-05,
#  'moves': 5.8544436010111e-05,
#  'reflect': 7.821729152323333e-05,
#  'rising': 6.421889292145742e-05,
#  'partisanship': 0.0004217288217868,
#  'societal': 2.1980722903636074e-05,
#  'shifts': 0.0001051354247934,
#  'greater': 8.652253310924709e-05,
#  'diversity': 0.0001967657709319,
#  'weakening': 3.789959007390533e-05,
#  'act': 1.4817055141584784e-05,
#  'possible': 0.0001745421195344,
#  'disentangle': 1.9295558954226465e-05,
#  'released': 0.0001518212280409,
#  'america': 0.0008814362713353,
#  'organization': 0.0003227096490322,
#  'based': 0.0001571252302046,
#  'underlined': 2.702481222544816e-05,
#  'particular': 0.0001619863707652,
#  'interfered': 1.9543600251628027e-05,
#  'year': 0.0001519673317533,
#  'likely': 0.0005567853701492,
#  'intensify': 2.677509476411519e-05,
#  'bret': 2.7035656990475818e-05,
#  'analyst': 2.9784607590307976e-05,
#  'alliance': 1.2267946020135734e-06,
#  'securing': 8.209450271293257e-06,
#  'democracy': 0.0004641860579809,
#  'initiative': 1.6921246135212932e-05,
#  'combat': 7.742903801899871e-05,
#  'undermine': 5.23599920767853e-06,
#  'institutions': 0.000117277608724,
#  'housed': 3.053281901972759e-06,
#  'german': 4.2398726269836944e-05,
#  'marshall': 1.2154010968031158e-05,
#  'fund': 0.0001694254714114,
#  'united': 0.0001701797001265,
#  'wrote': 0.0004318949376103,
#  'attack': 0.0001640717598532,
#  'wide': 1.211958163905153e-05,
#  'range': 0.0001161922165547,
#  'actors': 7.01012908871075e-05,
#  'dozen': 3.992337331305982e-05,
#  'new': 4.165036032783757e-05,
#  'decisions': 0.0002646697562646,
#  'limit': 0.0003605279504129,
#  'locations': 2.8943743373560205e-05,
#  'cast': 0.0004374279321998,
#  'findings': 4.265015966276654e-05,
#  'drew': 0.000180042087587,
#  'academic': 7.655989548238148e-05,
#  'highlight': 6.0165969660151134e-05,
#  'huge': 7.300168494830924e-05,
#  'run': 0.0001311382506827,
#  'agency': 0.0001058070882696,
#  'deployed': 1.942369835399456e-05,
#  'thousands': 9.625898200787726e-05,
#  'facebook': 7.606928916803859e-06,
#  'platforms': 8.953433001409559e-05,
#  'garnered': 2.575501425109933e-05,
#  'followers': 7.046336584444809e-05,
#  'posts': 1.4311956288195124e-05,
#  'highlighted': 7.034493066592856e-05,
#  'dozens': 4.804107933643711e-05,
#  'prominent': 5.641745578452349e-05,
#  'outlets': 0.0001140030743046,
#  'explicitly': 6.352319032742905e-05,
#  'implicitly': 1.583951776644346e-05,
#  'polls': 0.0005930845368956,
#  'effort': 0.0001949569291743,
#  'secure': 0.0003095452585037,
#  'republican': 0.0020257365701564,
#  'victory': 0.0004097235555761,
#  'bolstered': 2.019878958566542e-06,
#  'white': 0.0009943483422319,
#  'extremism': 7.743328182213453e-05,
#  'online': 0.0001072804674032,
#  'marc': 1.8036626143674407e-05,
#  'president': 0.0014861486030764,
#  'targeted': 0.0001333490461168,
#  'focused': 0.0001132307996219,
#  'intentionally': 0.0001386039830131,
#  'pouring': 4.083287677162674e-05,
#  'gasoline': 6.230757447443035e-05,
#  'division': 0.0002004176773286,
#  'warned': 5.920783806154002e-05,
#  'threat': 0.0001476827027126,
#  'persists': 2.3130046479160575e-05,
#  'officials': 0.001063223448781}

# %% [markdown]
# ### The reason why it doesn't work with the full list is that shifterator was using nltk tokenizer which ignores entities. Once that is fixed we will be good to go. I tried some things not sure why it doesn't works completely.
#
# ### Probably has to do something with using the exception condition for spacy.
#
# #### works alright with a NLTK tokenizer as long as the shifterator stuff is also using the same exact preprocessing method.

# %% [markdown]
# #### Draw graph

# %%
fig, ax = plt.subplots(figsize=(12, 12))
pos = nx.spring_layout(G, k=1)

#need a size map to adjust node size based on the shifterator score
#again these were made absolute so that their magnitude can be compared on the network graph
size_map = nx.get_node_attributes(G, "score")
size = list(size_map.values())


#need a color map to adjust node color based on the left vs. right leaning of the shifterator score 
#if the node attribute leaning is 'left' then we set the color blue
#if the node attribute leaning is 'right' then we set the color red
color_map = nx.get_node_attributes(G, 'leaning')
for key in color_map:
    if color_map[key]== 'left':
        color_map[key]= 'blue'
    if color_map[key]== 'right':
        color_map[key]= 'red'
partisan_cols = [color_map.get(node) for node in G.nodes()]
#partisan_cols

#scaling factor for edge weights
edges = G.edges()
weights = nx.get_edge_attributes(G, "weight")
scaling_factor = 0.04 # to emphasise differences 
alphas = [weights[edge] * scaling_factor for edge in edges]

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=16,
                 width = alphas,
                 edge_color='grey',
                 with_labels = False,
                 ax=ax, alpha = 0.5,
                node_color = partisan_cols,
                node_size = [x * 1000000 for x in size])



#Create offset labels 
#basically we create labels with white backround and align them horizontally
#we also specify how far the labels should be from the nodes

for key, value in pos.items():
    x, y = value[0]+.10, value[1]+.020
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='white', alpha=0.25),
            horizontalalignment='center', fontsize=13)
    
#we use tight layout to fit the graph inside the borders
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33434/1578590176.py in <module>
#      27
#      28 # Plot networks
# ---> 29 nx.draw_networkx(G, pos,
#      30                  font_size=16,
#      31                  width = alphas,
#
# /opt/conda/lib/python3.9/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     333         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     334
# --> 335     draw_networkx_nodes(G, pos, **node_kwds)
#     336     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     337     if with_labels:
#
# /opt/conda/lib/python3.9/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label)
#     464         alpha = None
#     465
# --> 466     node_collection = ax.scatter(
#     467         xy[:, 0],
#     468         xy[:, 1],
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4505                 (not np.issubdtype(s.dtype, np.floating) and
#    4506                  not np.issubdtype(s.dtype, np.integer))):
# -> 4507             raise ValueError(
#    4508                 "s must be a scalar, "
#    4509                 "or float array-like with the same size as x and y")
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y
