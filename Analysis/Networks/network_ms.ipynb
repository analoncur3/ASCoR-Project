# %% [markdown]
# # Create edgelist for network analysis of co-occuring words in newspaper titles

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import itertools
import unicodedata
from janome.tokenizer import Tokenizer
import networkx as nx
from scipy.spatial import distance
# %matplotlib inline
import matplotlib.pyplot as plt
from itertools import combinations
from collections import defaultdict
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import spacy
en = spacy.load('en_core_web_sm')
#save a sample of list
from random import sample
#define stopwords

# %%
data = pd.read_csv('preprocessed.csv', encoding='utf-8')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21436/1307149434.py in <module>
# ----> 1 data = pd.read_csv('preprocessed.csv', encoding='utf-8')
#       2 data
#
# NameError: name 'pd' is not defined

# %%
#get a sample 
df2 = data.sample(frac=0.01, replace=True, random_state=1)

# %%
stopwords = en.Defaults.stop_words
nlp.Defaults.stop_words.add('advertisement')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'whereafter', 'anything', 'ten', 'latterly', 'beforehand', 'whether', 'such', 'until', '’ve', 'well', 'either', 'although', 'former', 'where', 'should', 'with', 'own', 'and', 'again', 'quite', 'could', 'their', 'around', 'out', 'doing', '’ll', 'those', 'front', 'be', 'amount', 'down', 'one', 'each', 'moreover', 'most', 'were', 'amongst', 'cannot', 'hence', 'eleven', 'eight', 'below', 'sometime', 'too', 'yourself', 'seemed', 'please', 'between', 'three', 'indeed', 'also', 'into', 'now', 'among', 'this', 'what', 'nowhere', 'except', 'himself', 'still', 'done', 'the', 'together', 'on', 'get', 'yours', 'besides', 'always', 'further', 'to', 're', 'is', 'ever', 'that', 'whereby', 'whole', 'he', 'however', 'am', 'last', 'up', 'very', 'beside', 'many', 'have', 'none', 'something', 'really', 'toward', 'beyond', 'take', 'does', 'put', 'someone', 'why', '‘ve', 'anyone', 'alone', 'wherein', 'using', 'may', 'for', 'first', 'no', 'itself', 'than', 'even', 'thru', 'everywhere', 'has', 'hereupon', '’m', 'various', '’s', 'became', 'seem', 'sometimes', 'so', 'along', 'how', 'part', 'a', 'else', 'least', 'several', 'fifty', 'not', 'everything', 'its', 'four', 'hereby', 'see', 'more', 'twenty', 'ca', 'ourselves', 'can', 'thereafter', 'will', 'become', 'whenever', 'myself', 'thereby', 'twelve', 'name', 'neither', 'via', 'in', 'at', 'serious', 'say', 'since', 'behind', 'fifteen', 'would', 'elsewhere', 'over', 'here', 'forty', 'other', 'call', 'do', 'almost', 'we', '‘d', 'as', 'otherwise', 'somehow', 'advertisement', 'any', 'nevertheless', 'afterwards', 'two', 'themselves', 'through', '‘ll', 'every', 'thus', 'full', 'seems', 'herein', 'thence', 'them', 'nor', 'nine', 'whoever', 'top', 'both', 'across', 'herself', 'mostly', '‘re', 'meanwhile', 'nothing', 'him', 'us', 'because', 'our', 'throughout', 'before', 'much', 'made', 'by', 'which', 'these', 'n’t', 'had', 'while', 'empty', 'from', 'five', 'me', 'becomes', 'next', 'therefore', 'onto', 'some', 'seeming', 'then', 'against', 'off', 'must', 'wherever', 'during', 'anyway', 'whither', "'ll", 'used', 'perhaps', 'did', 'therein', 'his', 'less', '’d', 'are', 'once', 'unless', "'s", 'mine', 'hereafter', 'if', 'due', 'or', 'all', 'another', 'bottom', 'yourselves', 'anywhere', 'becoming', 'enough', 'about', 'whom', "'ve", 'n‘t', 'just', 'show', "'m", 'make', 'whereupon', 'they', 'never', 'towards', 'somewhere', "'d", 'per', "'re", 'sixty', 'hers', 'was', 'whence', 's', 'being', 'everyone', 'give', 'ours', 'regarding', '‘m', 'her', 'upon', 'after', 'there', 'it', 'of', 'side', 'whatever', 'others', 'latter', 'an', "n't", 'same', 'been', 'rather', 'i', 'few', 'go', 'within', 'keep', 'who', 'often', 'formerly', 'hundred', 'noone', 'you', 'move', 'whose', 'above', 'already', 'whereas', 'when', 'back', 'my', 'anyhow', 'yet', 'namely', 'only', 'though', 'your', 'but', 'nobody', 'third', 'without', 'she', '’re', 'might', 'six', 'thereupon', 'under', '‘s'}

# %%
def preprocessing(corpus):
    # initialize
    clean_text = []

    for row in corpus:
        tokens =nlp(''.join(str(row)))
        tokens = [clean_url(row) for row in corpus]
        #word tokenize
        tokens = word_tokenize(row)
        #lowercase
        tokens = [token.lower() for token in tokens]
        # isword
        tokens = [token for token in tokens if token.isalpha()]
        #remove stopwords
        tokens = [word for word in tokens if not word in stopwords]
        clean_sentence = ''
        clean_sentence = ' '.join(token for token in tokens)
        clean_text.append(clean_sentence)
        
    return clean_text

# %%
data['clean_text'] = preprocessing(data.astype(str)['maintext'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_328239/4042341365.py in <module>
# ----> 1 data['clean_text'] = preprocessing(data.astype(str)['maintext'])
#
# /tmp/ipykernel_328239/3982558488.py in preprocessing(corpus)
#       4
#       5     for row in corpus:
# ----> 6         tokens =nlp(''.join(str(row)))
#       7         tokens = [clean_url(row) for row in corpus]
#       8         #word tokenize
#
# /opt/conda/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1018                 error_handler = proc.get_error_handler()
#    1019             try:
# -> 1020                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1021             except KeyError as e:
#    1022                 # This typically happens if a component is not initialized
#
# /opt/conda/lib/python3.9/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /opt/conda/lib/python3.9/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.set_annotations()
#
# /opt/conda/lib/python3.9/site-packages/spacy/pipeline/_parser_internals/ner.pyx in spacy.pipeline._parser_internals.ner.BiluoPushDown.set_annotations()
#
# /opt/conda/lib/python3.9/site-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.Doc.set_ents()
#
# /opt/conda/lib/python3.9/site-packages/spacy/tokens/doc.pyx in spacy.tokens.doc.SetEntsDefault.values()
#
# /opt/conda/lib/python3.9/enum.py in __members__(cls)
#     417         return len(cls._member_names_)
#     418
# --> 419     @property
#     420     def __members__(cls):
#     421         """
#
# KeyboardInterrupt:

# %%
for row in data['clean_text']:
    docs = nlp(row)

# %%
docs.ents

# %% [markdown]
# #remove stopwords
#
# #text_tokens = word_tokenize(
# #tokens_without_sw = [word for word in text_tokens if not word in all_stopwords]
# #df2['clean_text'] = df2['clean_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %% [markdown]
# ### Create edge list from titles for igraph

# %%
texts = data.clean_title.to_list()
#from nltk.tokenize import word_tokenize
tokenized = [word_tokenize(e) for e in texts]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21436/3905164812.py in <module>
# ----> 1 texts = data.clean_title.to_list()
#       2 #from nltk.tokenize import word_tokenize
#       3 tokenized = [word_tokenize(e) for e in texts]
#
# NameError: name 'data' is not defined

# %%
edgelist = defaultdict(int)
for text in tokenized:
    for node1, node2 in combinations(text,2):
        edgelist[(node1,node2)]+=1

# %% [markdown]
# #### Save edgelist as .txt file

# %%
#for k, v in edgelist.items():
    #print(f"{k[0]},{k[1]},{v}")

with open("edgelist.txt", mode='w') as f:
    for k, v in edgelist.items():
        f.write(f"{k[0]},{k[1]},{v}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21436/1970948244.py in <module>
#       3
#       4 with open("edgelist.txt", mode='w') as f:
# ----> 5     for k, v in edgelist.items():
#       6         f.write(f"{k[0]},{k[1]},{v}\n")
#
# NameError: name 'edgelist' is not defined

# %%
filtered = {k: v for k, v in edgelist.items() if v > 30}

# %%
sorted_d = sorted(filtered.items(), key=operator.itemgetter(1), reverse = True)
#sorted_d

# %%
len(filtered)
# Out:
# 64

# %%
with open("edgelist_2.txt", mode='w') as f:
    for k, v in filtered.items():
        f.write(f"{k[0]},{k[1]},{v}\n")

# %%
import networkx as nx
import matplotlib.pyplot as plt
import operator

filtered = {k: v for k, v in edgelist.items() if v > 5} #retain only edges that co-occured at least 10 times 
#len(filtered)
#sort edgeweights
sorted_d = sorted(filtered.items(), key=operator.itemgetter(1), reverse = True)
#filter low weighted edges

#create graph object
G = nx.read_weighted_edgelist('edgelist_2.txt', delimiter=',')
#G.edges.data()
G.remove_nodes_from(list(nx.isolates(G)))
#draw graph
nx.draw(G, pos=nx.spring_layout(G, k=5, iterations=20), node_size = 10, with_labels = True, font_size = 15, font_family='sans-serif')
# draw subgraph for highlights
nx.draw_networkx(G.subgraph('voter'), pos=pos, font_size=16, node_color='red', font_color='black')

# %%
#write as graphml file so that igraph can open it
nx.write_graphml(G,'graph.graphml')

# %%
fig, ax = plt.subplots(figsize=(20, 20))
pos = nx.spring_layout(G, k=2)
edges = G.edges()
weights = nx.get_edge_attributes(G, “weight”)
scaling_factor = 0.04 # to emphasise differences
alphas = [weights[edge] * scaling_factor for edge in edges]

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=16,
                 width = alphas,
                 edge_color=‘grey’,
                 node_color=‘grey’,
                 with_labels = False,
                 ax=ax, alpha = 0.5)
nx.draw_networkx(G.subgraph(‘id’),
                 pos=pos,
                 font_size=16,
                 node_color=‘red’,
                 font_color=‘black’,
                ax =ax, alpha = 0.5)
nx.draw_networkx(G.subgraph(‘voter’),
                 pos=pos,
                 font_size=16,
                 node_color=‘blue’,
                 font_color=‘black’,
                ax =ax, alpha = 0.5)
# Create offset labels
for key, value in pos.items():
    x, y = value[0]+.10, value[1]+.020
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor=‘white’, alpha=0.25),
            horizontalalignment=‘center’, fontsize=13)
plt.tight_layout()
plt.show()
